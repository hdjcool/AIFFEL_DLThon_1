# %%
# 라이브러리 설치 및 임포트
import pandas as pd
import tensorflow as tf
from transformers import AutoTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, f1_score, confusion_matrix
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# %% [markdown]
# ### ModelCheckpoint 사용하면 코랩에서 에러 발생
# - history = train_model(model, train_dataset, val_dataset, EPOCHS, LEARNING_RATE, SAVE_PATH) 호출 될 때 optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) 에러가 남
#
# ```
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-cda70b969c54> in <cell line: 14>()
#      12
#      13 # # 학습 및 체크포인트 저장
# ---> 14 history = train_model(model, train_dataset, val_dataset, EPOCHS, LEARNING_RATE, SAVE_PATH)
#      15
#      16 # 손실 시각화
#
# 3 frames
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/optimizers/__init__.py in get(identifier, **kwargs)
#     333         )
#     334     else:
# --> 335         raise ValueError(
#     336             f"Could not interpret optimizer identifier: {identifier}"
#     337         )
#
# ValueError: Could not interpret optimizer identifier: <keras.src.optimizers.adam.Adam object at 0x7fa5c55342b0>
# ```
#
# #### 위 문제 디버깅 시 참고
# https://discuss.huggingface.co/t/pretrain-model-not-accepting-optimizer/76209/27

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 경고 메시지 억제

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# 설정
FILE_PATH = "final_data_emergency_added_preprocessed_241208.csv"
TEST_FILE_PATH = "test.csv"
SAVE_PATH = "best_klue-bert_model_weights_2412081140.h5"
FINAL_SAVE_PATH = "final_klue-bert_model_2412081140"
OUTPUT_FILE = "submission_klue-bert_2412081140.csv"
OUTPUT_CSV_FILE ="test_with_predictions_klue-bert_2412081140.csv"
PRETRAINED_MODEL_NAME = "klue/bert-base"
MAX_LENGTH = 128
BATCH_SIZE = 16
EPOCHS = 200
LEARNING_RATE = 5e-5

# %%
# 클래스 매핑 정의
class_mapping = {
    "협박 대화": 0,
    "갈취 대화": 1,
    "직장 내 괴롭힘 대화": 2,
    "기타 괴롭힘 대화": 3,
    "일반 대화": 4
}

# class_mapping에서 클래스 이름 리스트 생성
class_labels = [k for k, v in sorted(class_mapping.items(), key=lambda item: item[1])]

# 클래스 수 계산
num_classes = len(class_mapping)

print("Class Labels:", class_labels)
print("Number of Classes:", num_classes)
# Out:
# Class Labels: ['협박 대화', '갈취 대화', '직장 내 괴롭힘 대화', '기타 괴롭힘 대화', '일반 대화']
# Number of Classes: 5

# %%
def load_data(file_path, text_column='conversation', label_column='class'):
    """
    CSV 파일에서 데이터를 로드하고 텍스트와 레이블을 반환하며, 레이블을 숫자로 매핑합니다.
    Args:
    - file_path (str): 데이터 파일 경로
    - text_column (str): 텍스트가 저장된 열 이름 (기본값: 'conversation')
    - label_column (str): 레이블이 저장된 열 이름 (기본값: 'class')
    Returns:
    - texts (list of str): 입력 텍스트 리스트
    - labels (list of str): 클래스 레이블 리스트
    - mapped_labels (list of int): 숫자로 매핑된 클래스 레이블 리스트
    """
    # 데이터 로드
    data = pd.read_csv(file_path)

    # NaN 값 제거
    data = data.dropna(subset=[text_column, label_column])

    # 텍스트와 레이블 열 추출
    texts = data[text_column].tolist()
    labels = data[label_column].tolist()

    # 레이블을 숫자로 매핑
    mapped_labels = [class_mapping[label] for label in labels]

    # 텍스트 데이터와 레이블 정리
    cleaned_data = [
        (text, label, mapped_label) 
        for text, label, mapped_label in zip(texts, labels, mapped_labels)
        if isinstance(text, str) and text.strip()  # 문자열이 아니거나 빈 텍스트 제거
    ]
    texts, labels, mapped_labels = zip(*cleaned_data)

    return list(texts), list(labels), list(mapped_labels)

# %%
import math

# dataset 확인용 test 코드
file_path = FILE_PATH
texts, labels, mapped_labels = load_data(file_path)

# 숫자 -> 클래스 이름 디코딩
decoded_labels = [class_labels[label] for label in mapped_labels]

# 각 클래스별 갯수 계산
class_counts = Counter(labels)

# 출력
print("Mapped Labels:", mapped_labels[:5])
print("Class Names:", decoded_labels[:5])
print("Class Counts:", dict(class_counts))

print(type(texts))
print(any(text == "" for text in texts))  # 빈 문자열 확인
print(any(text is None for text in texts))  # None 값 확인

# NaN 확인
contains_nan = any(isinstance(text, float) and math.isnan(text) for text in texts)
print("NaN 포함 여부:", contains_nan)

# NaN 값 위치 출력
nan_indices = [i for i, text in enumerate(texts) if isinstance(text, float) and math.isnan(text)]
print("NaN 값 위치:", nan_indices)

print(type(mapped_labels))
print(all(isinstance(label, int) for label in mapped_labels))  # 모든 레이블이 int인지 확인
# Out:
# Mapped Labels: [0, 0, 3, 1, 1]
# Class Names: ['협박 대화', '협박 대화', '기타 괴롭힘 대화', '갈취 대화', '갈취 대화']
# Class Counts: {'협박 대화': 896, '기타 괴롭힘 대화': 1094, '갈취 대화': 981, '직장 내 괴롭힘 대화': 979, '일반 대화': 1668}
# <class 'list'>
# False
# False
# NaN 포함 여부: False
# NaN 값 위치: []
# <class 'list'>
# True

# %%
# 데이터 준비 함수 정의
def prepare_data(texts, mapped_labels, tokenizer, max_length, batch_size):
    """
    데이터를 전처리하여 TensorFlow Dataset으로 변환합니다.
    Args:
    - texts (list of str): 입력 텍스트
    - mapped_labels (list): 숫자로 매핑된 클래스 레이블
    - tokenizer: Hugging Face Tokenizer
    - max_length (int): 토큰화된 입력의 최대 길이
    - batch_size (int): 배치 크기
    Returns:
    - train_dataset, val_dataset: 학습과 검증에 사용할 TensorFlow Dataset
    - val_texts, val_labels: 검증 데이터 (추가적인 분석을 위해 반환)
    """
    # 1. 데이터 나누기
    # train_test_split에서 stratify를 추가하여 클래스 비율이 학습 데이터와 검증 데이터에 동일하게 유지
    train_texts, val_texts, train_labels, val_labels = train_test_split(
        texts, mapped_labels, test_size=0.2, random_state=42, stratify=mapped_labels
    )
    
    print(f"Train texts: {len(train_texts)}, Val texts: {len(val_texts)}")
    
    def tokenize(texts, labels):
        """
        입력 텍스트를 토크나이즈하고 TensorFlow 텐서로 변환합니다.
        Args:
        - texts (list of str): 입력 텍스트 리스트
        - labels (list): 숫자 레이블 리스트
        Returns:
        - inputs (dict): 토크나이즈된 입력 데이터
        - labels_tensor (tf.Tensor): TensorFlow 형식의 레이블 데이터
        """
        inputs = tokenizer(
            texts,
            padding="max_length",
            truncation=True,
            max_length=max_length,
            return_tensors="tf"
        )
        labels_tensor = tf.convert_to_tensor(labels, dtype=tf.int32)
        print(f"Tokenized input shapes: {inputs['input_ids'].shape}")
        return dict(inputs), labels_tensor
    
    # 2. TensorFlow Dataset 생성
    train_inputs, train_labels = tokenize(train_texts, train_labels)
    val_inputs, val_labels = tokenize(val_texts, val_labels)
    
    train_dataset = tf.data.Dataset.from_tensor_slices((dict(train_inputs), train_labels))
    val_dataset = tf.data.Dataset.from_tensor_slices((dict(val_inputs), val_labels))

    # 배치 처리
    train_dataset = train_dataset.shuffle(len(train_texts)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    # 3. 데이터 반환
    return train_dataset, val_dataset, val_texts, val_labels

# %%
# BERT 백본 레이어 프리징 함수 정의
def freeze_bert_layers(model, layer_name_prefix="bert"):
    """
    특정 레이어(예: BERT 백본 레이어)의 가중치를 프리징합니다.
    Args:
    - model: TensorFlow Keras 모델
    - layer_name_prefix (str): 프리징할 레이어의 이름 접두사 (기본값: 'bert')
    """
    for layer in model.layers:
        if layer_name_prefix in layer.name:
            layer.trainable = False
    print(f"Layers starting with '{layer_name_prefix}' have been frozen.")

# %% [markdown]
# #### 분류 헤드 추가
# 1. TFBertForSequenceClassification 클래스:
#  - Hugging Face에서 제공하는 KLUE-BERT 기반 분류 모델 클래스입니다.
#  - 이 클래스는 [CLS] 토큰 출력 위에 분류를 수행하는 Dense 레이어가 이미 정의되어 있습니다.
#  - num_labels 매개변수로 분류할 클래스의 개수를 지정합니다.
#
# 2. Dense 레이어 자동 추가:
#  - KLUE-BERT의 [CLS] 토큰 출력은 모델의 첫 번째 토큰에 해당하는 벡터입니다.
#  - TFBertForSequenceClassification은 이 [CLS] 토큰을 입력으로 받아, Dropout과 Dense 레이어를 통해 클래스 확률 분포를 출력합니다.
# ---
# #### Dense 레이어의 동작
#  - TFBertForSequenceClassification 내부 동작을 요약하면 다음과 같습니다:
# 1. KLUE-BERT 출력:
#   - 입력 문장을 토큰화한 후 KLUE-BERT에 전달.
#   - KLUE-BERT는 각 토큰에 대한 벡터 출력(문장 벡터 포함).
# 2. [CLS] 토큰 선택:
#   - KLUE-BERT 출력의 첫 번째 벡터(문장 전체를 대표하는 [CLS] 토큰)를 선택.
# 3. Dense 레이어:
#   - [CLS] 토큰에 Dropout을 적용한 후, 분류 작업을 위한 Dense 레이어를 추가.

# %%
# 모델 구성 함수 정의
def build_model(pretrained_model_name, num_labels, freeze_backbone=False):
    """
    KLUE-BERT를 기반으로 분류 모델을 구성합니다.
    Args:
    - pretrained_model_name (str): 사전 학습 모델 이름
    - num_labels (int): 클래스 수
    - freeze_backbone (bool): BERT 백본 레이어 프리징 여부
    Returns:
    - model: TensorFlow Keras 모델
    """
    model = TFBertForSequenceClassification.from_pretrained(
        pretrained_model_name, 
        num_labels=num_labels, 
        from_pt=True)
    
    # BERT 백본 레이어 프리징 (옵션)
    if freeze_backbone:
        freeze_bert_layers(model)

    # 모델 출력 확인 (디버깅용)
    print(model.summary())

    return model

# %%
# 학습 함수 정의
def train_model(model, train_dataset, val_dataset, epochs, learning_rate, save_path, patience=5):
    """
    모델을 학습시키고 가장 좋은 모델을 저장합니다.
    Args:
    - model: TensorFlow Keras 모델
    - train_dataset: 학습 데이터셋
    - val_dataset: 검증 데이터셋
    - epochs (int): 학습 에폭 수
    - learning_rate (float): 학습률
    - save_path (str): 가장 좋은 모델을 저장할 경로
    - patience (int): 조기 종료를 위한 검증 손실 모니터링 에폭 수
    Returns:
    - history: 학습 기록
    """
    # 모델 컴파일
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    metrics = ["accuracy"]
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    # 체크포인트 콜백 정의
    checkpoint = ModelCheckpoint(
        filepath=save_path,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
        mode="min",
        verbose=1
    )

    # 조기 종료 콜백 추가
    early_stopping = EarlyStopping(
        monitor="val_loss",
        patience=patience,
        mode="min",
        verbose=1,
        restore_best_weights=True
    )

    # 모델 학습
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=[checkpoint, early_stopping]
    )

    return history

# %%
# 손실 시각화
def plot_loss(history):
    """
    학습 및 검증 손실을 시각화합니다.
    Args:
    - history: 모델 학습 기록
    """
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# F1 Score 계산
def calculate_f1_score(model, tokenizer, val_texts, val_labels, class_labels, max_length):
    """
    검증 데이터에 대해 F1 Score를 계산합니다.
    Args:
    - model: 학습된 모델
    - tokenizer: Hugging Face Tokenizer
    - val_texts: 검증 데이터 텍스트
    - val_labels: 검증 데이터 레이블
    - class_labels: 클래스 이름 리스트
    - max_length: 입력 텍스트의 최대 길이
    Returns:
    - y_true_classes: 실제 클래스 레이블
    - y_pred_classes: 예측된 클래스 레이블
    """
    # 검증 데이터 토크나이징
    inputs = tokenizer(
        val_texts,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

    # 예측
    predictions = model.predict(dict(inputs))
    predicted_classes = tf.argmax(predictions.logits, axis=1).numpy()

    # F1 Score 계산
    f1_weighted = f1_score(val_labels, predicted_classes, average="weighted")
    f1_per_class = f1_score(val_labels, predicted_classes, average=None)
    print(f"Weighted F1 Score: {f1_weighted}\n")

    # F1 Score per class 출력
    print("F1 Score per class:")
    for label, score in zip(class_labels, f1_per_class):
        print(f"{label}: {score:.4f}")

    # Classification Report 출력
    print("\nClassification Report:")
    print(classification_report(val_labels, predicted_classes, target_names=class_labels))

    return val_labels, predicted_classes

# %%
# 가장 좋은 모델 로드 함수 정의
def load_best_model(model, save_path):
    """
    저장된 가장 좋은 모델의 가중치를 로드합니다.
    Args:
    - model: 초기화된 모델
    - save_path (str): 저장된 체크포인트 파일 경로
    Returns:
    - model: 가중치를 로드한 모델
    """
    model.load_weights(save_path)
    print(f"Best model loaded from {save_path}")
    return model

# %%
# 모델 및 토크나이저 저장 함수 정의
def save_model_and_tokenizer(model, tokenizer, save_path):
    """
    모델과 토크나이저를 저장합니다.
    Args:
    - model: 학습된 모델
    - tokenizer: Hugging Face Tokenizer
    - save_path (str): 모델 저장 경로
    """
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print(f"Model and tokenizer saved to {save_path}")

# %%
# 테스트 데이터 로드 함수 정의
def load_test_data(file_path):
    """
    테스트 데이터를 로드합니다.
    Args:
    - file_path (str): 테스트 데이터 파일 경로
    Returns:
    - df_test: pandas DataFrame (idx와 text 열 포함)
    """
    df_test = pd.read_csv(file_path)
    return df_test

# %%
def predict_and_create_submission(model, tokenizer, test_data, output_file, class_labels, max_length=128):
    """
    학습된 모델을 사용해 테스트 데이터를 예측하고, 캐글 제출용 CSV 파일 생성.
    Args:
    - model: 학습된 TensorFlow 모델
    - tokenizer: Hugging Face Tokenizer
    - test_data: pandas DataFrame (idx, text 열 포함)
    - output_file (str): 생성할 submission.csv 파일 경로
    - class_labels (list of str): 클래스 이름 리스트
    - max_length (int): 토큰화된 입력의 최대 길이
    Returns:
    - None (submission.csv 파일 생성)
    """
    # 입력 텍스트 추출
    texts = test_data['text'].tolist()

    # 데이터 토크나이징
    inputs = tokenizer(
        texts,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

    # 모델 예측
    predictions = model.predict(dict(inputs))
    predicted_classes = tf.argmax(predictions.logits, axis=1).numpy()

    # 클래스 이름으로 변환 (필요 시 사용)
    predicted_labels = [class_labels[cls] for cls in predicted_classes]

    # 결과를 DataFrame으로 변환
    submission = pd.DataFrame({
        "idx": test_data['idx'],      # 파일 이름 또는 고유 식별자
        "target": predicted_classes   # 정수형 클래스 ID
    })

    # CSV 파일 저장
    submission.to_csv(output_file, index=False)
    print(f"Submission file saved to {output_file}")

# %%
# 데이터 로드 및 전처리
texts, labels, mapped_labels = load_data(FILE_PATH)  # mapped_labels 포함
tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)

# 데이터셋 생성
train_dataset, val_dataset, val_texts, val_labels = prepare_data(
    texts, mapped_labels, tokenizer, MAX_LENGTH, BATCH_SIZE
)
# Out:
# Train texts: 4494, Val texts: 1124
# Tokenized input shapes: (4494, 128)
# Tokenized input shapes: (1124, 128)

# %%
# 모델 생성
model = build_model(PRETRAINED_MODEL_NAME, num_labels=num_classes, freeze_backbone=True)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Layers starting with 'bert' have been frozen.
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bert (TFBertMainLayer)       multiple                  110617344
# _________________________________________________________________
# dropout_37 (Dropout)         multiple                  0
# _________________________________________________________________
# classifier (Dense)           multiple                  3845
# =================================================================
# Total params: 110,621,189
# Trainable params: 3,845
# Non-trainable params: 110,617,344
# _________________________________________________________________
# None

# %% [markdown]
# ```
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ```
# #### 경고 원인
# 1. 모델 간의 아키텍처 차이:
#
# - 예를 들어, **BertForPreTraining**과 **BertForSequenceClassification**은 다른 아키텍처를 가집니다.
# - BertForPreTraining에는 다음과 같은 추가 가중치가 포함됩니다:
#  - cls.predictions.*: 언어 모델링(MLM, Masked Language Modeling)용 레이어.
#  - cls.seq_relationship.*: 문장 관계 예측(NSP, Next Sentence Prediction)용 레이어.
# - TFBertModel은 기본적으로 Transformer Encoder만 포함하므로, 언어 모델링이나 문장 관계 예측을 위한 가중치는 사용되지 않습니다.
#
# 2. PyTorch -> TensorFlow 변환:
# - Hugging Face의 PyTorch 모델을 TensorFlow 모델로 변환할 때, 특정 가중치는 TensorFlow 모델의 요구사항에 맞지 않아 제외될 수 있습니다.
# - 이는 변환 과정에서 자연스러운 현상이며, 모델의 주요 기능에는 영향을 미치지 않습니다.

# %%
# 모델 학습
history = train_model(model, train_dataset, val_dataset, EPOCHS, LEARNING_RATE, SAVE_PATH)
# Out:
# Epoch 1/200
# 281/281 [==============================] - 63s 182ms/step - loss: 1.4313 - accuracy: 0.4321 - val_loss: 1.3005 - val_accuracy: 0.5596
#
# Epoch 00001: val_loss improved from inf to 1.30051, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 2/200
# 281/281 [==============================] - 50s 177ms/step - loss: 1.2373 - accuracy: 0.5903 - val_loss: 1.1369 - val_accuracy: 0.6770
#
# Epoch 00002: val_loss improved from 1.30051 to 1.13687, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 3/200
# 281/281 [==============================] - 51s 180ms/step - loss: 1.1078 - accuracy: 0.6638 - val_loss: 1.0232 - val_accuracy: 0.7180
#
# Epoch 00003: val_loss improved from 1.13687 to 1.02316, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 4/200
# 281/281 [==============================] - 51s 182ms/step - loss: 1.0177 - accuracy: 0.6983 - val_loss: 0.9401 - val_accuracy: 0.7429
#
# Epoch 00004: val_loss improved from 1.02316 to 0.94013, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 5/200
# 281/281 [==============================] - 52s 184ms/step - loss: 0.9393 - accuracy: 0.7187 - val_loss: 0.8766 - val_accuracy: 0.7553
#
# Epoch 00005: val_loss improved from 0.94013 to 0.87657, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 6/200
# 281/281 [==============================] - 52s 184ms/step - loss: 0.8880 - accuracy: 0.7350 - val_loss: 0.8270 - val_accuracy: 0.7696
#
# Epoch 00006: val_loss improved from 0.87657 to 0.82701, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 7/200
# 281/281 [==============================] - 52s 185ms/step - loss: 0.8371 - accuracy: 0.7466 - val_loss: 0.7837 - val_accuracy: 0.7589
#
# Epoch 00007: val_loss improved from 0.82701 to 0.78374, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 8/200
# 281/281 [==============================] - 52s 186ms/step - loss: 0.8057 - accuracy: 0.7534 - val_loss: 0.7484 - val_accuracy: 0.7883
#
# Epoch 00008: val_loss improved from 0.78374 to 0.74841, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 9/200
# 281/281 [==============================] - 52s 186ms/step - loss: 0.7720 - accuracy: 0.7626 - val_loss: 0.7190 - val_accuracy: 0.7874
#
# Epoch 00009: val_loss improved from 0.74841 to 0.71897, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 10/200
# 281/281 [==============================] - 52s 186ms/step - loss: 0.7500 - accuracy: 0.7675 - val_loss: 0.6941 - val_accuracy: 0.7963
#
# Epoch 00010: val_loss improved from 0.71897 to 0.69407, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 11/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.7241 - accuracy: 0.7672 - val_loss: 0.6755 - val_accuracy: 0.7998
#
# Epoch 00011: val_loss improved from 0.69407 to 0.67552, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 12/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.7020 - accuracy: 0.7788 - val_loss: 0.6547 - val_accuracy: 0.8016
#
# Epoch 00012: val_loss improved from 0.67552 to 0.65471, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 13/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.6933 - accuracy: 0.7786 - val_loss: 0.6434 - val_accuracy: 0.7936
#
# Epoch 00013: val_loss improved from 0.65471 to 0.64342, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 14/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6738 - accuracy: 0.7844 - val_loss: 0.6288 - val_accuracy: 0.8043
#
# Epoch 00014: val_loss improved from 0.64342 to 0.62884, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 15/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6572 - accuracy: 0.7850 - val_loss: 0.6135 - val_accuracy: 0.8114
#
# Epoch 00015: val_loss improved from 0.62884 to 0.61345, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 16/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.6481 - accuracy: 0.7904 - val_loss: 0.6039 - val_accuracy: 0.8060
#
# Epoch 00016: val_loss improved from 0.61345 to 0.60393, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 17/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.6340 - accuracy: 0.7942 - val_loss: 0.5960 - val_accuracy: 0.8043
#
# Epoch 00017: val_loss improved from 0.60393 to 0.59601, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 18/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6247 - accuracy: 0.7991 - val_loss: 0.5829 - val_accuracy: 0.8141
#
# Epoch 00018: val_loss improved from 0.59601 to 0.58293, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 19/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6129 - accuracy: 0.8020 - val_loss: 0.5744 - val_accuracy: 0.8141
#
# Epoch 00019: val_loss improved from 0.58293 to 0.57442, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 20/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6108 - accuracy: 0.7897 - val_loss: 0.5665 - val_accuracy: 0.8176
#
# Epoch 00020: val_loss improved from 0.57442 to 0.56648, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 21/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6024 - accuracy: 0.7986 - val_loss: 0.5598 - val_accuracy: 0.8158
#
# Epoch 00021: val_loss improved from 0.56648 to 0.55977, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 22/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.5858 - accuracy: 0.8062 - val_loss: 0.5546 - val_accuracy: 0.8132
#
# Epoch 00022: val_loss improved from 0.55977 to 0.55460, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 23/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.5862 - accuracy: 0.8008 - val_loss: 0.5505 - val_accuracy: 0.8149
#
# Epoch 00023: val_loss improved from 0.55460 to 0.55051, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 24/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5826 - accuracy: 0.7991 - val_loss: 0.5450 - val_accuracy: 0.8185
#
# Epoch 00024: val_loss improved from 0.55051 to 0.54500, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 25/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5715 - accuracy: 0.8126 - val_loss: 0.5383 - val_accuracy: 0.8167
#
# Epoch 00025: val_loss improved from 0.54500 to 0.53826, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 26/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5690 - accuracy: 0.8051 - val_loss: 0.5344 - val_accuracy: 0.8141
#
# Epoch 00026: val_loss improved from 0.53826 to 0.53442, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 27/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5625 - accuracy: 0.8055 - val_loss: 0.5293 - val_accuracy: 0.8212
#
# Epoch 00027: val_loss improved from 0.53442 to 0.52932, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 28/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5654 - accuracy: 0.7988 - val_loss: 0.5260 - val_accuracy: 0.8141
#
# Epoch 00028: val_loss improved from 0.52932 to 0.52603, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 29/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5615 - accuracy: 0.8022 - val_loss: 0.5201 - val_accuracy: 0.8238
#
# Epoch 00029: val_loss improved from 0.52603 to 0.52012, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 30/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.5525 - accuracy: 0.8084 - val_loss: 0.5174 - val_accuracy: 0.8194
#
# Epoch 00030: val_loss improved from 0.52012 to 0.51745, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 31/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5503 - accuracy: 0.8097 - val_loss: 0.5134 - val_accuracy: 0.8238
#
# Epoch 00031: val_loss improved from 0.51745 to 0.51338, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 32/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.5502 - accuracy: 0.8084 - val_loss: 0.5116 - val_accuracy: 0.8230
#
# Epoch 00032: val_loss improved from 0.51338 to 0.51156, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 33/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5376 - accuracy: 0.8166 - val_loss: 0.5077 - val_accuracy: 0.8203
#
# Epoch 00033: val_loss improved from 0.51156 to 0.50774, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 34/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5396 - accuracy: 0.8129 - val_loss: 0.5054 - val_accuracy: 0.8221
#
# Epoch 00034: val_loss improved from 0.50774 to 0.50543, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 35/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5427 - accuracy: 0.8104 - val_loss: 0.5051 - val_accuracy: 0.8212
#
# Epoch 00035: val_loss improved from 0.50543 to 0.50509, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 36/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5373 - accuracy: 0.8124 - val_loss: 0.5007 - val_accuracy: 0.8176
#
# Epoch 00036: val_loss improved from 0.50509 to 0.50074, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 37/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5365 - accuracy: 0.8102 - val_loss: 0.4998 - val_accuracy: 0.8221
#
# Epoch 00037: val_loss improved from 0.50074 to 0.49981, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 38/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5317 - accuracy: 0.8102 - val_loss: 0.4960 - val_accuracy: 0.8221
#
# Epoch 00038: val_loss improved from 0.49981 to 0.49603, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 39/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5174 - accuracy: 0.8233 - val_loss: 0.4923 - val_accuracy: 0.8238
#
# Epoch 00039: val_loss improved from 0.49603 to 0.49232, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 40/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5176 - accuracy: 0.8191 - val_loss: 0.4926 - val_accuracy: 0.8256
#
# Epoch 00040: val_loss did not improve from 0.49232
# Epoch 41/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5201 - accuracy: 0.8200 - val_loss: 0.4894 - val_accuracy: 0.8230
#
# Epoch 00041: val_loss improved from 0.49232 to 0.48940, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 42/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5170 - accuracy: 0.8153 - val_loss: 0.4874 - val_accuracy: 0.8247
#
# Epoch 00042: val_loss improved from 0.48940 to 0.48743, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 43/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5167 - accuracy: 0.8222 - val_loss: 0.4866 - val_accuracy: 0.8256
#
# Epoch 00043: val_loss improved from 0.48743 to 0.48659, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 44/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5146 - accuracy: 0.8258 - val_loss: 0.4839 - val_accuracy: 0.8238
#
# Epoch 00044: val_loss improved from 0.48659 to 0.48386, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 45/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5153 - accuracy: 0.8160 - val_loss: 0.4820 - val_accuracy: 0.8292
#
# Epoch 00045: val_loss improved from 0.48386 to 0.48202, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 46/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5043 - accuracy: 0.8178 - val_loss: 0.4810 - val_accuracy: 0.8265
#
# Epoch 00046: val_loss improved from 0.48202 to 0.48104, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 47/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5123 - accuracy: 0.8200 - val_loss: 0.4784 - val_accuracy: 0.8292
#
# Epoch 00047: val_loss improved from 0.48104 to 0.47845, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 48/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5061 - accuracy: 0.8186 - val_loss: 0.4775 - val_accuracy: 0.8274
#
# Epoch 00048: val_loss improved from 0.47845 to 0.47748, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 49/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5017 - accuracy: 0.8255 - val_loss: 0.4756 - val_accuracy: 0.8274
#
# Epoch 00049: val_loss improved from 0.47748 to 0.47556, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 50/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5070 - accuracy: 0.8273 - val_loss: 0.4749 - val_accuracy: 0.8363
#
# Epoch 00050: val_loss improved from 0.47556 to 0.47487, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 51/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.5019 - accuracy: 0.8240 - val_loss: 0.4725 - val_accuracy: 0.8301
#
# Epoch 00051: val_loss improved from 0.47487 to 0.47250, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 52/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4933 - accuracy: 0.8309 - val_loss: 0.4730 - val_accuracy: 0.8327
#
# Epoch 00052: val_loss did not improve from 0.47250
# Epoch 53/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4942 - accuracy: 0.8336 - val_loss: 0.4701 - val_accuracy: 0.8319
#
# Epoch 00053: val_loss improved from 0.47250 to 0.47006, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 54/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4938 - accuracy: 0.8278 - val_loss: 0.4696 - val_accuracy: 0.8327
#
# Epoch 00054: val_loss improved from 0.47006 to 0.46960, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 55/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4964 - accuracy: 0.8249 - val_loss: 0.4674 - val_accuracy: 0.8336
#
# Epoch 00055: val_loss improved from 0.46960 to 0.46738, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 56/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4879 - accuracy: 0.8324 - val_loss: 0.4654 - val_accuracy: 0.8345
#
# Epoch 00056: val_loss improved from 0.46738 to 0.46544, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 57/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4959 - accuracy: 0.8258 - val_loss: 0.4676 - val_accuracy: 0.8363
#
# Epoch 00057: val_loss did not improve from 0.46544
# Epoch 58/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4883 - accuracy: 0.8296 - val_loss: 0.4651 - val_accuracy: 0.8319
#
# Epoch 00058: val_loss improved from 0.46544 to 0.46513, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 59/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4860 - accuracy: 0.8275 - val_loss: 0.4650 - val_accuracy: 0.8354
#
# Epoch 00059: val_loss improved from 0.46513 to 0.46503, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 60/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4903 - accuracy: 0.8249 - val_loss: 0.4612 - val_accuracy: 0.8354
#
# Epoch 00060: val_loss improved from 0.46503 to 0.46121, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 61/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4865 - accuracy: 0.8287 - val_loss: 0.4621 - val_accuracy: 0.8363
#
# Epoch 00061: val_loss did not improve from 0.46121
# Epoch 62/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4930 - accuracy: 0.8291 - val_loss: 0.4607 - val_accuracy: 0.8354
#
# Epoch 00062: val_loss improved from 0.46121 to 0.46068, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 63/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4865 - accuracy: 0.8313 - val_loss: 0.4601 - val_accuracy: 0.8336
#
# Epoch 00063: val_loss improved from 0.46068 to 0.46006, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 64/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4898 - accuracy: 0.8331 - val_loss: 0.4596 - val_accuracy: 0.8345
#
# Epoch 00064: val_loss improved from 0.46006 to 0.45961, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 65/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4859 - accuracy: 0.8309 - val_loss: 0.4588 - val_accuracy: 0.8354
#
# Epoch 00065: val_loss improved from 0.45961 to 0.45880, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 66/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4820 - accuracy: 0.8287 - val_loss: 0.4556 - val_accuracy: 0.8372
#
# Epoch 00066: val_loss improved from 0.45880 to 0.45564, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 67/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4836 - accuracy: 0.8275 - val_loss: 0.4569 - val_accuracy: 0.8390
#
# Epoch 00067: val_loss did not improve from 0.45564
# Epoch 68/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4690 - accuracy: 0.8344 - val_loss: 0.4565 - val_accuracy: 0.8390
#
# Epoch 00068: val_loss did not improve from 0.45564
# Epoch 69/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4766 - accuracy: 0.8329 - val_loss: 0.4548 - val_accuracy: 0.8372
#
# Epoch 00069: val_loss improved from 0.45564 to 0.45483, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 70/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4767 - accuracy: 0.8378 - val_loss: 0.4534 - val_accuracy: 0.8372
#
# Epoch 00070: val_loss improved from 0.45483 to 0.45340, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 71/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4792 - accuracy: 0.8358 - val_loss: 0.4523 - val_accuracy: 0.8381
#
# Epoch 00071: val_loss improved from 0.45340 to 0.45229, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 72/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4863 - accuracy: 0.8258 - val_loss: 0.4523 - val_accuracy: 0.8345
#
# Epoch 00072: val_loss did not improve from 0.45229
# Epoch 73/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4693 - accuracy: 0.8382 - val_loss: 0.4530 - val_accuracy: 0.8372
#
# Epoch 00073: val_loss did not improve from 0.45229
# Epoch 74/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4746 - accuracy: 0.8318 - val_loss: 0.4503 - val_accuracy: 0.8399
#
# Epoch 00074: val_loss improved from 0.45229 to 0.45029, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 75/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4708 - accuracy: 0.8244 - val_loss: 0.4498 - val_accuracy: 0.8399
#
# Epoch 00075: val_loss improved from 0.45029 to 0.44982, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 76/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4756 - accuracy: 0.8289 - val_loss: 0.4487 - val_accuracy: 0.8416
#
# Epoch 00076: val_loss improved from 0.44982 to 0.44872, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 77/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4653 - accuracy: 0.8360 - val_loss: 0.4506 - val_accuracy: 0.8399
#
# Epoch 00077: val_loss did not improve from 0.44872
# Epoch 78/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4668 - accuracy: 0.8380 - val_loss: 0.4490 - val_accuracy: 0.8425
#
# Epoch 00078: val_loss did not improve from 0.44872
# Epoch 79/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4700 - accuracy: 0.8367 - val_loss: 0.4479 - val_accuracy: 0.8434
#
# Epoch 00079: val_loss improved from 0.44872 to 0.44787, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 80/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4528 - accuracy: 0.8396 - val_loss: 0.4465 - val_accuracy: 0.8399
#
# Epoch 00080: val_loss improved from 0.44787 to 0.44647, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 81/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4629 - accuracy: 0.8342 - val_loss: 0.4481 - val_accuracy: 0.8381
#
# Epoch 00081: val_loss did not improve from 0.44647
# Epoch 82/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4648 - accuracy: 0.8329 - val_loss: 0.4468 - val_accuracy: 0.8372
#
# Epoch 00082: val_loss did not improve from 0.44647
# Epoch 83/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4684 - accuracy: 0.8311 - val_loss: 0.4450 - val_accuracy: 0.8434
#
# Epoch 00083: val_loss improved from 0.44647 to 0.44498, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 84/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4583 - accuracy: 0.8382 - val_loss: 0.4442 - val_accuracy: 0.8416
#
# Epoch 00084: val_loss improved from 0.44498 to 0.44420, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 85/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4658 - accuracy: 0.8313 - val_loss: 0.4440 - val_accuracy: 0.8416
#
# Epoch 00085: val_loss improved from 0.44420 to 0.44397, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 86/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4719 - accuracy: 0.8282 - val_loss: 0.4437 - val_accuracy: 0.8461
#
# Epoch 00086: val_loss improved from 0.44397 to 0.44371, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 87/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4562 - accuracy: 0.8322 - val_loss: 0.4439 - val_accuracy: 0.8425
#
# Epoch 00087: val_loss did not improve from 0.44371
# Epoch 88/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4567 - accuracy: 0.8367 - val_loss: 0.4430 - val_accuracy: 0.8425
#
# Epoch 00088: val_loss improved from 0.44371 to 0.44302, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 89/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4585 - accuracy: 0.8362 - val_loss: 0.4437 - val_accuracy: 0.8407
#
# Epoch 00089: val_loss did not improve from 0.44302
# Epoch 90/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4591 - accuracy: 0.8405 - val_loss: 0.4418 - val_accuracy: 0.8443
#
# Epoch 00090: val_loss improved from 0.44302 to 0.44184, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 91/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4585 - accuracy: 0.8420 - val_loss: 0.4420 - val_accuracy: 0.8434
#
# Epoch 00091: val_loss did not improve from 0.44184
# Epoch 92/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4561 - accuracy: 0.8347 - val_loss: 0.4408 - val_accuracy: 0.8407
#
# Epoch 00092: val_loss improved from 0.44184 to 0.44077, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 93/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4571 - accuracy: 0.8433 - val_loss: 0.4403 - val_accuracy: 0.8434
#
# Epoch 00093: val_loss improved from 0.44077 to 0.44031, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 94/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4567 - accuracy: 0.8362 - val_loss: 0.4422 - val_accuracy: 0.8434
#
# Epoch 00094: val_loss did not improve from 0.44031
# Epoch 95/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4514 - accuracy: 0.8369 - val_loss: 0.4406 - val_accuracy: 0.8461
#
# Epoch 00095: val_loss did not improve from 0.44031
# Epoch 96/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4515 - accuracy: 0.8431 - val_loss: 0.4392 - val_accuracy: 0.8452
#
# Epoch 00096: val_loss improved from 0.44031 to 0.43917, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 97/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4558 - accuracy: 0.8387 - val_loss: 0.4381 - val_accuracy: 0.8488
#
# Epoch 00097: val_loss improved from 0.43917 to 0.43814, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 98/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4547 - accuracy: 0.8371 - val_loss: 0.4392 - val_accuracy: 0.8452
#
# Epoch 00098: val_loss did not improve from 0.43814
# Epoch 99/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4530 - accuracy: 0.8396 - val_loss: 0.4384 - val_accuracy: 0.8434
#
# Epoch 00099: val_loss did not improve from 0.43814
# Epoch 100/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4570 - accuracy: 0.8333 - val_loss: 0.4373 - val_accuracy: 0.8461
#
# Epoch 00100: val_loss improved from 0.43814 to 0.43730, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 101/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4502 - accuracy: 0.8402 - val_loss: 0.4371 - val_accuracy: 0.8479
#
# Epoch 00101: val_loss improved from 0.43730 to 0.43710, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 102/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4485 - accuracy: 0.8382 - val_loss: 0.4370 - val_accuracy: 0.8452
#
# Epoch 00102: val_loss improved from 0.43710 to 0.43699, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 103/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4571 - accuracy: 0.8344 - val_loss: 0.4353 - val_accuracy: 0.8488
#
# Epoch 00103: val_loss improved from 0.43699 to 0.43534, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 104/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4526 - accuracy: 0.8431 - val_loss: 0.4358 - val_accuracy: 0.8488
#
# Epoch 00104: val_loss did not improve from 0.43534
# Epoch 105/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4407 - accuracy: 0.8436 - val_loss: 0.4364 - val_accuracy: 0.8461
#
# Epoch 00105: val_loss did not improve from 0.43534
# Epoch 106/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4442 - accuracy: 0.8449 - val_loss: 0.4361 - val_accuracy: 0.8505
#
# Epoch 00106: val_loss did not improve from 0.43534
# Epoch 107/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4534 - accuracy: 0.8407 - val_loss: 0.4364 - val_accuracy: 0.8496
#
# Epoch 00107: val_loss did not improve from 0.43534
# Epoch 108/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4460 - accuracy: 0.8385 - val_loss: 0.4345 - val_accuracy: 0.8514
#
# Epoch 00108: val_loss improved from 0.43534 to 0.43454, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 109/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4476 - accuracy: 0.8442 - val_loss: 0.4348 - val_accuracy: 0.8470
#
# Epoch 00109: val_loss did not improve from 0.43454
# Epoch 110/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4573 - accuracy: 0.8340 - val_loss: 0.4344 - val_accuracy: 0.8461
#
# Epoch 00110: val_loss improved from 0.43454 to 0.43437, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 111/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4504 - accuracy: 0.8360 - val_loss: 0.4339 - val_accuracy: 0.8443
#
# Epoch 00111: val_loss improved from 0.43437 to 0.43391, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 112/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4426 - accuracy: 0.8373 - val_loss: 0.4330 - val_accuracy: 0.8461
#
# Epoch 00112: val_loss improved from 0.43391 to 0.43296, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 113/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4455 - accuracy: 0.8474 - val_loss: 0.4335 - val_accuracy: 0.8488
#
# Epoch 00113: val_loss did not improve from 0.43296
# Epoch 114/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4481 - accuracy: 0.8338 - val_loss: 0.4340 - val_accuracy: 0.8488
#
# Epoch 00114: val_loss did not improve from 0.43296
# Epoch 115/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4418 - accuracy: 0.8400 - val_loss: 0.4339 - val_accuracy: 0.8443
#
# Epoch 00115: val_loss did not improve from 0.43296
# Epoch 116/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4425 - accuracy: 0.8456 - val_loss: 0.4320 - val_accuracy: 0.8443
#
# Epoch 00116: val_loss improved from 0.43296 to 0.43199, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 117/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4475 - accuracy: 0.8429 - val_loss: 0.4308 - val_accuracy: 0.8541
#
# Epoch 00117: val_loss improved from 0.43199 to 0.43084, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 118/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4478 - accuracy: 0.8398 - val_loss: 0.4313 - val_accuracy: 0.8461
#
# Epoch 00118: val_loss did not improve from 0.43084
# Epoch 119/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4338 - accuracy: 0.8482 - val_loss: 0.4310 - val_accuracy: 0.8496
#
# Epoch 00119: val_loss did not improve from 0.43084
# Epoch 120/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4497 - accuracy: 0.8369 - val_loss: 0.4315 - val_accuracy: 0.8505
#
# Epoch 00120: val_loss did not improve from 0.43084
# Epoch 121/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4488 - accuracy: 0.8364 - val_loss: 0.4318 - val_accuracy: 0.8443
#
# Epoch 00121: val_loss did not improve from 0.43084
# Epoch 122/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4497 - accuracy: 0.8387 - val_loss: 0.4306 - val_accuracy: 0.8470
#
# Epoch 00122: val_loss improved from 0.43084 to 0.43060, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 123/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4267 - accuracy: 0.8505 - val_loss: 0.4301 - val_accuracy: 0.8496
#
# Epoch 00123: val_loss improved from 0.43060 to 0.43009, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 124/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4414 - accuracy: 0.8405 - val_loss: 0.4297 - val_accuracy: 0.8479
#
# Epoch 00124: val_loss improved from 0.43009 to 0.42971, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 125/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4464 - accuracy: 0.8494 - val_loss: 0.4298 - val_accuracy: 0.8488
#
# Epoch 00125: val_loss did not improve from 0.42971
# Epoch 126/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4348 - accuracy: 0.8429 - val_loss: 0.4290 - val_accuracy: 0.8505
#
# Epoch 00126: val_loss improved from 0.42971 to 0.42904, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 127/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4329 - accuracy: 0.8422 - val_loss: 0.4287 - val_accuracy: 0.8496
#
# Epoch 00127: val_loss improved from 0.42904 to 0.42873, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 128/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4497 - accuracy: 0.8380 - val_loss: 0.4286 - val_accuracy: 0.8514
#
# Epoch 00128: val_loss improved from 0.42873 to 0.42857, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 129/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4383 - accuracy: 0.8445 - val_loss: 0.4286 - val_accuracy: 0.8496
#
# Epoch 00129: val_loss did not improve from 0.42857
# Epoch 130/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4351 - accuracy: 0.8442 - val_loss: 0.4279 - val_accuracy: 0.8496
#
# Epoch 00130: val_loss improved from 0.42857 to 0.42792, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 131/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4381 - accuracy: 0.8511 - val_loss: 0.4283 - val_accuracy: 0.8505
#
# Epoch 00131: val_loss did not improve from 0.42792
# Epoch 132/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4385 - accuracy: 0.8416 - val_loss: 0.4277 - val_accuracy: 0.8505
#
# Epoch 00132: val_loss improved from 0.42792 to 0.42769, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 133/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4353 - accuracy: 0.8405 - val_loss: 0.4276 - val_accuracy: 0.8479
#
# Epoch 00133: val_loss improved from 0.42769 to 0.42762, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 134/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4348 - accuracy: 0.8471 - val_loss: 0.4276 - val_accuracy: 0.8541
#
# Epoch 00134: val_loss improved from 0.42762 to 0.42758, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 135/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4357 - accuracy: 0.8478 - val_loss: 0.4272 - val_accuracy: 0.8470
#
# Epoch 00135: val_loss improved from 0.42758 to 0.42717, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 136/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4349 - accuracy: 0.8440 - val_loss: 0.4266 - val_accuracy: 0.8496
#
# Epoch 00136: val_loss improved from 0.42717 to 0.42655, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 137/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4324 - accuracy: 0.8487 - val_loss: 0.4277 - val_accuracy: 0.8505
#
# Epoch 00137: val_loss did not improve from 0.42655
# Epoch 138/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4326 - accuracy: 0.8442 - val_loss: 0.4250 - val_accuracy: 0.8505
#
# Epoch 00138: val_loss improved from 0.42655 to 0.42500, saving model to best_klue-bert_model_weights_2412081140.h5
# Epoch 139/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4347 - accuracy: 0.8447 - val_loss: 0.4287 - val_accuracy: 0.8470
#
# Epoch 00139: val_loss did not improve from 0.42500
# Epoch 140/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4322 - accuracy: 0.8480 - val_loss: 0.4252 - val_accuracy: 0.8514
#
# Epoch 00140: val_loss did not improve from 0.42500
# Epoch 141/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.4432 - accuracy: 0.8385 - val_loss: 0.4265 - val_accuracy: 0.8461
#
# Epoch 00141: val_loss did not improve from 0.42500
# Epoch 142/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4395 - accuracy: 0.8422 - val_loss: 0.4266 - val_accuracy: 0.8496
#
# Epoch 00142: val_loss did not improve from 0.42500
# Epoch 143/200
# 281/281 [==============================] - 53s 187ms/step - loss: 0.4396 - accuracy: 0.8445 - val_loss: 0.4262 - val_accuracy: 0.8479
#
# Epoch 00143: val_loss did not improve from 0.42500
# Restoring model weights from the end of the best epoch.
# Epoch 00143: early stopping

# %%
# 학습 손실 시각화
if 'loss' in history.history and 'val_loss' in history.history:
    plot_loss(history)

# %%
# 가장 좋은 모델 로드
model = load_best_model(model, SAVE_PATH)
print("Best model weights loaded.")

# 학습 완료 후 전체 모델과 토크나이저 저장
save_model_and_tokenizer(model, tokenizer, FINAL_SAVE_PATH)
print(f"Model and tokenizer saved to {FINAL_SAVE_PATH}")
# Out:
# Best model loaded from best_klue-bert_model_weights_2412081140.h5
# Best model weights loaded.
# Model and tokenizer saved to final_klue-bert_model_2412081140
# Model and tokenizer saved to final_klue-bert_model_2412081140

# %%
# F1 Score 계산 및 예측 값 반환
y_true_classes, y_pred_classes = calculate_f1_score(model, tokenizer, val_texts, val_labels, class_labels, MAX_LENGTH)
# Out:
# Weighted F1 Score: 0.8501421221355522
#
# F1 Score per class:
# 협박 대화: 0.7600
# 갈취 대화: 0.8107
# 직장 내 괴롭힘 대화: 0.8673
# 기타 괴롭힘 대화: 0.7648
# 일반 대화: 0.9675
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        협박 대화       0.78      0.74      0.76       179
#        갈취 대화       0.85      0.78      0.81       196
#  직장 내 괴롭힘 대화       0.87      0.87      0.87       196
#    기타 괴롭힘 대화       0.74      0.79      0.76       219
#        일반 대화       0.96      0.98      0.97       334
#
#     accuracy                           0.85      1124
#    macro avg       0.84      0.83      0.83      1124
# weighted avg       0.85      0.85      0.85      1124

# %%
# import matplotlib.font_manager as fm

# # 설치된 글꼴 목록 출력
# for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
#     print(fm.FontProperties(fname=font).get_name())

# %%
import matplotlib.font_manager as fm

# 한글 글꼴 설정
# plt.rcParams['font.family'] = 'AppleGothic'  # MacOS
plt.rcParams['font.family'] = 'NanumGothic'  # Linux
# plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
# Confusion Matrix 계산
cm = confusion_matrix(y_true_classes, y_pred_classes, labels=range(len(class_labels)))

# Confusion Matrix 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.title("Confusion Matrix")
plt.show()

# %%
# 테스트 데이터 로드
df_test = pd.read_csv(TEST_FILE_PATH)

# 테스트 데이터 예측 및 제출 파일 생성
predict_and_create_submission(
    model=model,
    tokenizer=tokenizer,
    test_data=df_test,
    output_file=OUTPUT_FILE,
    class_labels=class_labels,
    max_length=MAX_LENGTH
)
# Out:
# Submission file saved to submission_klue-bert_2412081140.csv

# %%
# 간이 테스트 함수
def predict_class(model, tokenizer, texts, class_labels=None, max_length=128):
    """
    분류 모델을 사용해 입력 텍스트의 클래스를 예측합니다.
    
    Args:
    - model: 학습된 TensorFlow 분류 모델.
    - tokenizer: Hugging Face 토크나이저.
    - texts (list of str): 예측할 문장 리스트.
    - class_labels (list of str, optional): 클래스 이름 리스트. None이면 이름은 None 반환.
    - max_length (int): 토큰화된 입력의 최대 길이. 기본값 128.
    
    Returns:
    - list of tuple: 각 입력 문장에 대해 (클래스 인덱스, 클래스 이름) 튜플 리스트.
    """
    # 텍스트를 토크나이징
    inputs = tokenizer(
        texts,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="tf"
    )

    # 모델 예측
    predictions = model.predict(dict(inputs))
    predicted_classes = tf.argmax(predictions.logits, axis=1).numpy()

    # 클래스 이름 반환 여부
    results = []
    for cls in predicted_classes:
        cls_name = class_labels[cls] if class_labels else None
        results.append((cls, cls_name))

    return results

# %%
# 테스트 데이터
test_texts = [
    "아가씨 담배한갑주소 네 4500원입니다 어 네 지갑어디갔지 에이 버스에서 잃어버렸나보네 그럼 취소할까요 아가씨 내 여기단골이니 담에 갖다줄께 저도 알바생이라 외상안됩니다 아따 누가 떼먹는다고 그러나 갖다준다고 안됩니다 자꾸이럼 경찰불러요 아가씨 담배피는교 그건 왜 물으세요 그람 아가씨 담배 한대만 빌립시다 내 지금 지갑도 잃어버리고 기분이 그래서 그러니 여기요  아따 주는김에 한개더 주면 되겠네",
    "우리팀에서 다른팀으로 갈 사람 없나? 그럼 영지씨가 가는건 어때?  네? 제가요? 그렇지? 2달만 파견 잘 갔다오면 승진이야. 네? 저는 별로 가고 싶지 않습니다. 여기 있는 모든사람도 가기 싫어해. 그러니까 막내인 영지씨가 가는게 맞지 정말 죄송합니다. 저는 못갑니다. 장난해? 모두를 위해 영지씨가 희생하는게 싫어? 네. 부당한 방법으로 가는 것 같습니다. 영지씨 안가면 회사생활 오래 못할 것 같은데 그래도 안갈거야? 안가면 지옥일텐데. 그래도 이 방법은 아닌 것 같습니다. 죄송합니다.",
    "너 오늘 그게 뭐야 네 제가 뭘 잘못했나요.? 제대로 좀 하지 네 똑바로 좀 하지 행실이 맘에 안들어 네 실천할께요 옆에 동기들 좀 본받으란 말야 어? 네 알겠습니다 그래 똑바로해 노럭할께요",
    "이거 들어바 와 이 노래 진짜 좋다 그치 요즘 이 것만 들어 진짜 너무 좋다 내가 요즘 듣는 것도 들어봐 음 난 좀 별론데 좋을 줄 알았는데 아쉽네 내 취향은 아닌 듯 배고프다 밥이나 먹으러 가자 그래",
    "아무튼 앞으로 니가 내 와이파이야. .응 와이파이 온. 켰어. 반말? 주인님이라고도 말해야지? .켰습니다. 주인님. 오냐. 앞으로도 잘부탁한다 와이파이. 넵. 이렇게만 해? 알겠지? 응."
]

# 모델을 사용해 예측
predictions = predict_class(model, tokenizer, test_texts, class_labels=class_labels, max_length=MAX_LENGTH)

# 결과 출력
for idx, (text, (cls_index, cls_name)) in enumerate(zip(test_texts, predictions)):
    print(f"[{idx+1}] Text: {text}")
    print(f"    → Predicted Class Index: {cls_index}")
    print(f"    → Predicted Class Name: {cls_name}\n")
# Out:
# [1] Text: 아가씨 담배한갑주소 네 4500원입니다 어 네 지갑어디갔지 에이 버스에서 잃어버렸나보네 그럼 취소할까요 아가씨 내 여기단골이니 담에 갖다줄께 저도 알바생이라 외상안됩니다 아따 누가 떼먹는다고 그러나 갖다준다고 안됩니다 자꾸이럼 경찰불러요 아가씨 담배피는교 그건 왜 물으세요 그람 아가씨 담배 한대만 빌립시다 내 지금 지갑도 잃어버리고 기분이 그래서 그러니 여기요  아따 주는김에 한개더 주면 되겠네
#     → Predicted Class Index: 1
#     → Predicted Class Name: 갈취 대화
#
# [2] Text: 우리팀에서 다른팀으로 갈 사람 없나? 그럼 영지씨가 가는건 어때?  네? 제가요? 그렇지? 2달만 파견 잘 갔다오면 승진이야. 네? 저는 별로 가고 싶지 않습니다. 여기 있는 모든사람도 가기 싫어해. 그러니까 막내인 영지씨가 가는게 맞지 정말 죄송합니다. 저는 못갑니다. 장난해? 모두를 위해 영지씨가 희생하는게 싫어? 네. 부당한 방법으로 가는 것 같습니다. 영지씨 안가면 회사생활 오래 못할 것 같은데 그래도 안갈거야? 안가면 지옥일텐데. 그래도 이 방법은 아닌 것 같습니다. 죄송합니다.
#     → Predicted Class Index: 2
#     → Predicted Class Name: 직장 내 괴롭힘 대화
#
# [3] Text: 너 오늘 그게 뭐야 네 제가 뭘 잘못했나요.? 제대로 좀 하지 네 똑바로 좀 하지 행실이 맘에 안들어 네 실천할께요 옆에 동기들 좀 본받으란 말야 어? 네 알겠습니다 그래 똑바로해 노럭할께요
#     → Predicted Class Index: 3
#     → Predicted Class Name: 기타 괴롭힘 대화
#
# [4] Text: 이거 들어바 와 이 노래 진짜 좋다 그치 요즘 이 것만 들어 진짜 너무 좋다 내가 요즘 듣는 것도 들어봐 음 난 좀 별론데 좋을 줄 알았는데 아쉽네 내 취향은 아닌 듯 배고프다 밥이나 먹으러 가자 그래
#     → Predicted Class Index: 4
#     → Predicted Class Name: 일반 대화
#
# [5] Text: 아무튼 앞으로 니가 내 와이파이야. .응 와이파이 온. 켰어. 반말? 주인님이라고도 말해야지? .켰습니다. 주인님. 오냐. 앞으로도 잘부탁한다 와이파이. 넵. 이렇게만 해? 알겠지? 응.
#     → Predicted Class Index: 3
#     → Predicted Class Name: 기타 괴롭힘 대화

# %%
def process_and_save_predictions(model, tokenizer, input_file, output_file, class_labels, max_length=128):
    """
    테스트 데이터를 예측하고 클래스 이름을 추가한 뒤 저장합니다.

    Args:
    - model: 학습된 TensorFlow 분류 모델.
    - tokenizer: Hugging Face 토크나이저.
    - input_file (str): 입력 CSV 파일 경로 (test.csv).
    - output_file (str): 예측 결과를 저장할 CSV 파일 경로.
    - class_labels (list of str): 클래스 이름 리스트.
    - max_length (int): 토큰화된 입력의 최대 길이. 기본값 128.
    """
    # 테스트 데이터 읽기
    try:
        test_data = pd.read_csv(input_file)
    except Exception as e:
        print(f"Error reading input file: {e}")
        return

    # 입력 데이터 확인
    if 'text' not in test_data.columns:
        print("Error: The input file must contain a 'text' column.")
        return
    
    # 예측할 텍스트 열 추출
    texts = test_data['text'].tolist()

    # 클래스 예측
    predictions = predict_class(model, tokenizer, texts, class_labels, max_length)

    # 예측 결과를 데이터프레임에 추가
    test_data['predicted_class_index'] = [pred[0] for pred in predictions]  # 클래스 인덱스
    test_data['predicted_class_name'] = [pred[1] for pred in predictions]  # 클래스 이름

    # 클래스별 추론 갯수 계산 및 출력
    class_counts = Counter(test_data['predicted_class_name'])
    print("\nClass Prediction Counts:")
    for class_name, count in class_counts.items():
        print(f"{class_name}: {count}")

    # 결과 저장
    try:
        test_data.to_csv(output_file, index=False)
        print(f"\nPredictions saved to {output_file}")
    except Exception as e:
        print(f"Error saving output file: {e}")

# %%
process_and_save_predictions(
    model=model,  # 학습된 모델
    tokenizer=tokenizer,  # Hugging Face 토크나이저
    input_file=TEST_FILE_PATH,  # 입력 파일 경로
    output_file=OUTPUT_CSV_FILE,  # 저장할 출력 파일 경로
    class_labels=class_labels,  # 클래스 이름
    max_length=128  # 최대 길이
)
# Out:
# Class Prediction Counts:
# 갈취 대화: 91
# 직장 내 괴롭힘 대화: 93
# 기타 괴롭힘 대화: 131
# 일반 대화: 79
# 협박 대화: 106
#
# Predictions saved to test_with_predictions_klue-bert_2412081140.csv
